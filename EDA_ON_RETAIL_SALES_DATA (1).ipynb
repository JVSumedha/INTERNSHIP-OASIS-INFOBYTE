# %% [markdown]
# # **EDA ON RETAIL SALES DATA**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/retail_sales_dataset.csv")

# %%
df.head(5)
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.tail(5)
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.drop_duplicates()
df
#No duplicates found
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
#modal values
df.mode().dropna()
# Out:
#    Transaction ID        Date Customer ID  Gender   Age Product Category  \
# 0               1  2023-05-16     CUST001  Female  43.0         Clothing
#
#    Quantity  Price per Unit  Total Amount
# 0       4.0            50.0          50.0

# %%
df=df.sort_values(by="Date")
df.head(5)
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 521             522  2023-01-01     CUST522    Male   46           Beauty
# 179             180  2023-01-01     CUST180    Male   41         Clothing
# 558             559  2023-01-01     CUST559  Female   40         Clothing
# 302             303  2023-01-02     CUST303    Male   19      Electronics
# 978             979  2023-01-02     CUST979  Female   19           Beauty
#
#      Quantity  Price per Unit  Total Amount
# 521         3             500          1500
# 179         3             300           900
# 558         4             300          1200
# 302         3              30            90
# 978         1              25            25

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
#Obatining a plot of total amount using seaborn
plt.figure(figsize=(15,5))
sns.lineplot(x="Date",y="Total Amount",data=df)
plt.show()

# %% [markdown]
# TIME SERIES ANALYSIS BY MONTH

# %%
df["Month"]=df["Date"].dt.month
df["Year"]=df["Date"].dt.year

# %%
#Total monthly sales
Monthly_sales=df.groupby(["Year","Month"],as_index=False)["Total Amount"].sum()
df["Monthly sales"]=Monthly_sales["Total Amount"]

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x="Date",y="Monthly sales",data=df)
plt.show()

# %%
#deleting Month,Year and Monthly sales columns for customer and product analysis.
df=df.drop(["Month","Year","Monthly sales"],axis=1)
df.head(10)
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 521             522 2023-01-01     CUST522    Male   46           Beauty
# 179             180 2023-01-01     CUST180    Male   41         Clothing
# 558             559 2023-01-01     CUST559  Female   40         Clothing
# 302             303 2023-01-02     CUST303    Male   19      Electronics
# 978             979 2023-01-02     CUST979  Female   19           Beauty
# 162             163 2023-01-02     CUST163  Female   64         Clothing
# 420             421 2023-01-02     CUST421  Female   37         Clothing
# 609             610 2023-01-03     CUST610  Female   26           Beauty
# 682             683 2023-01-04     CUST683    Male   38           Beauty
# 230             231 2023-01-04     CUST231  Female   23         Clothing
#
#      Quantity  Price per Unit  Total Amount
# 521         3             500          1500
# 179         3             300           900
# ...

# %% [markdown]
# CUSTOMER AND PRODUCT ANALYSIS

# %%
#Age analysis
age_bins=[10,20,30,40,50,60]
age_labels=['10-19','20-29','30-39','40-49','50+']
df["Age group"]=pd.cut(df["Age"],bins=age_bins,labels=age_labels,right=True)

# %%
#Calcuating the total amount spent by each age group
Total_amount_by_age=df.groupby('Age group')['Total Amount'].sum()
print(Total_amount_by_age)
# Out:
# Age group
# 10-19     34730
# 20-29     98215
# 30-39     95950
# 40-49     93795
# 50+      100085
# Name: Total Amount, dtype: int64
# <ipython-input-30-5c6bb1424361>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Total_amount_by_age=df.groupby('Age group')['Total Amount'].sum()

# %%
#grouping age group and product category and calculating the sum of spending.
Grouped_data=df.groupby(["Age group","Product Category"])["Total Amount"].sum().reset_index()
# Group by Age Group and sum the Total Amount
AgeGroup_sales = df.groupby("Age group")["Total Amount"].sum().reset_index()

# Calculate percentage contribution
AgeGroup_sales['Percentage'] = (AgeGroup_sales['Total Amount'] / AgeGroup_sales['Total Amount'].sum()) * 100

# Display results
print(AgeGroup_sales)
# Out:
#   Age group  Total Amount  Percentage
# 0     10-19         34730    8.214771
# 1     20-29         98215   23.231033
# 2     30-39         95950   22.695287
# 3     40-49         93795   22.185560
# 4       50+        100085   23.673349
# <ipython-input-45-6c295abd647f>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Grouped_data=df.groupby(["Age group","Product Category"])["Total Amount"].sum().reset_index()
# <ipython-input-45-6c295abd647f>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   AgeGroup_sales = df.groupby("Age group")["Total Amount"].sum().reset_index()

# %%
#creating a bar plot to visualize spending patterns by age group and product category.
plt.figure(figsize=(8,6))
sns.barplot(x="Age group",y="Total Amount",hue="Product Category",data=Grouped_data)
plt.title("Spending patterns by age group and prodcut category")
plt.xlabel("Age Group")
plt.ylabel("Total Amount")
plt.show()

# %% [markdown]
# GENDER SPENDING ANALYSIS

# %%
Gender_Totalspend=df.groupby('Gender')['Total Amount'].sum().reset_index()
print(Gender_Totalspend)
# Out:
#    Gender  Total Amount
# 0  Female        232840
# 1    Male        223160

# %%
plt.figure(figsize=(5,5))
plt.bar(Gender_Totalspend['Gender'],Gender_Totalspend['Total Amount'],color=['pink','black'])
plt.title("Total Amount spent by each gender")
plt.xlabel("Gender")
plt.ylabel("Total Amount")
plt.show()

# %%
#Product preference by gender
Gender_preference=df.groupby(["Gender","Product Category"])["Total Amount"].sum().reset_index()
Gender_Totalspend['Percentage'] = (Gender_Totalspend['Total Amount'] / Gender_Totalspend['Total Amount'].sum()) * 100
print(Gender_Totalspend)
# Out:
#    Gender  Total Amount  Percentage
# 0  Female        232840   51.061404
# 1    Male        223160   48.938596

# %%
plt.figure(figsize=(7,7))
sns.barplot(x="Gender",y="Total Amount",hue="Product Category",data=Gender_preference)
plt.title("Gender product preference")
plt.xlabel("Gender")
plt.ylabel("Total Amount")
plt.show()

# %%
#Average spend of total males and females
Avg_amount_by_gender=df.groupby('Gender')['Total Amount'].mean()
print(Avg_amount_by_gender)
# Out:
# Gender
# Female    456.549020
# Male      455.428571
# Name: Total Amount, dtype: float64

# %% [markdown]
# PRODUCT PERFORMANCE ANALYSIS

# %%
#Total revenue from each product category
Total_revenue=df.groupby("Product Category")["Total Amount"].sum().reset_index()
print(Total_revenue)
Gender_Totalspend['Percentage'] = (Gender_Totalspend['Total Amount'] / Gender_Totalspend['Total Amount'].sum()) * 100
print(Gender_Totalspend)
# Out:
#   Product Category  Total Amount
# 0           Beauty        143515
# 1         Clothing        155580
# 2      Electronics        156905

# %%
plt.figure(figsize=(5,5))
plt.bar(Total_revenue['Product Category'],Total_revenue['Total Amount'],color=['green','black','orange'])
plt.title("Total revenue from each product")
plt.xlabel("Product Category")
plt.ylabel("Total Amount")
plt.show()

# %%
Total_num=df.groupby("Product Category")["Quantity"].sum().reset_index()
print(Total_num)
# Group by Product Category and sum the Total Amount
Product_sales = df.groupby("Product Category")["Total Amount"].sum().reset_index()
# Calculate percentage contribution
Product_sales['Percentage'] = (Product_sales['Total Amount'] / Product_sales['Total Amount'].sum()) * 100
# Display results
print(Product_sales)
# Out:
#   Product Category  Quantity
# 0           Beauty       771
# 1         Clothing       894
# 2      Electronics       849
#   Product Category  Total Amount  Percentage
# 0           Beauty        143515   31.472588
# 1         Clothing        155580   34.118421
# 2      Electronics        156905   34.408991

# %% [markdown]
# RECOMMENDATIONS/SUGGESSTIONS
#
# 1.Strengthening online presence that show higher inclination towards digital channels to improve sales.
#
#
# 2.Offer age-group based discounts to increase client turnover for groups that are not performing well.
#
# 3.Create product bundles,this pushes sales for the product that not getting saled.
#
# 4.Engage with community through events or patnership that align with the interests of each age group.
#
# 5.Collect feedback from customers in each age group/Gendergroups to understand their needs and expectations better.
